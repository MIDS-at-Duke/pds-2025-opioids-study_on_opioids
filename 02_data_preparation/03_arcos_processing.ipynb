# %% [markdown]
# ## ARCOS Data Processing
#
# Process ARCOS (Automation of Reports and Consolidated Orders System) dataset to create county-year aggregated opioid distribution data. This notebook handles large-scale transaction data, calculates morphine milligram equivalents (MME), and implements quality controls including outlier detection and data validation.

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import os
from pathlib import Path

pd.set_option("mode.copy_on_write", True)

# %% [markdown]
# ### Define Validation Functions
#
# Helper functions for data quality checks throughout the processing pipeline.

# %%
def validate_file_exists(filepath):
    if not os.path.exists(filepath):
        raise FileNotFoundError(f"Required file not found: {filepath}")
    return True


def validate_columns(df, required_cols, dataset_name="dataset"):
    missing = set(required_cols) - set(df.columns)
    if missing:
        raise ValueError(f"{dataset_name} missing required columns: {missing}")
    return True


def validate_year_range(df, year_col, min_year, max_year):
    invalid = df[(df[year_col] < min_year) | (df[year_col] > max_year)]
    if len(invalid) > 0:
        print(
            f"Warning: {len(invalid)} records with years outside {min_year}-{max_year}"
        )
        print(f"  Year range found: {df[year_col].min()} to {df[year_col].max()}")
    return len(invalid)


def validate_positive_values(df, col, allow_zero=False):
    threshold = 0 if allow_zero else 0
    invalid = df[df[col] <= threshold] if not allow_zero else df[df[col] < threshold]
    if len(invalid) > 0:
        print(f"Warning: {len(invalid)} records with non-positive {col}")
    return len(invalid)


def validate_merge_success(df_before, df_after, merge_type="merge"):
    before_count = len(df_before)
    after_count = len(df_after)
    if after_count < before_count:
        loss_pct = 100 * (before_count - after_count) / before_count
        print(
            f"Warning: {merge_type} resulted in {before_count - after_count} lost rows ({loss_pct:.1f}%)"
        )
    return after_count


def check_duplicates(df, subset_cols):
    dupes = df.duplicated(subset=subset_cols)
    dupe_count = dupes.sum()
    if dupe_count > 0:
        print(f"Warning: {dupe_count} duplicate records found on {subset_cols}")
    return dupe_count

# %% [markdown]
# ### Initial Data Exploration
#
# Load a small sample to verify file structure and identify available columns.

# %% [markdown]
# ### Input Validation
#
# Verify file exists and contains required columns before full processing.

# %%
# Define required columns and expected states
required_cols = [
    "BUYER_STATE",
    "BUYER_COUNTY",
    "TRANSACTION_DATE",
    "MME_Conversion_Factor",
    "CALC_BASE_WT_IN_GM",
]

selected_states = ["FL", "WA", "NC", "GA", "OR", "SC", "ID", "MT", "UT"]

# Validate sample has required columns
validate_columns(sample, required_cols, "ARCOS sample")

print(f"\nValidation passed. Required columns present.")
print(f"Processing {len(selected_states)} states: {', '.join(selected_states)}")
# Out:
# Validation passed. Required columns present.
# Processing 9 states: FL, WA, NC, GA, OR, SC, ID, MT, UT

# %%
filepath = "../01_data/raw/arcos/arcos_all.zip"

# Verify file exists before attempting to load
validate_file_exists(filepath)

sample = pd.read_csv(filepath, compression="zip", nrows=100, delimiter="\t")

print(f"Sample data shape: {sample.shape}")
print(f"\nColumns: {list(sample.columns)}")
print(f"\nUnique drugs: {sample['DRUG_NAME'].unique()}")
# Out:
# Sample data shape: (100, 33)
#
# Columns: ['REPORTER_DEA_NO', 'REPORTER_BUS_ACT', 'REPORTER_NAME', 'REPORTER_ADDL_CO_INFO', 'REPORTER_ADDRESS1', 'REPORTER_ADDRESS2', 'REPORTER_CITY', 'REPORTER_STATE', 'REPORTER_ZIP', 'REPORTER_COUNTY', 'BUYER_DEA_NO', 'BUYER_BUS_ACT', 'BUYER_NAME', 'BUYER_ADDL_CO_INFO', 'BUYER_ADDRESS1', 'BUYER_ADDRESS2', 'BUYER_CITY', 'BUYER_STATE', 'BUYER_ZIP', 'BUYER_COUNTY', 'TRANSACTION_CODE', 'DRUG_CODE', 'NDC_NO', 'DRUG_NAME', 'Measure', 'MME_Conversion_Factor', 'Dosage_Strength', 'TRANSACTION_DATE', 'Combined_Labeler_Name', 'Reporter_family', 'CALC_BASE_WT_IN_GM', 'DOSAGE_UNIT', 'MME']
#
# Unique drugs: ['CODEINE' 'OXYCODONE' 'HYDROCODONE' 'METHADONE' 'FENTANYL'
#  'BUPRENORPHINE' 'MORPHINE' 'OXYMORPHONE']

# %% [markdown]
# ### Process Full Dataset
#
# Process complete ARCOS data in chunks to manage memory. Filter to target states, calculate MME values, and aggregate to county-year level.

# %%
# Keep track of processing stats
chunks = []
total_records_processed = 0
total_records_kept = 0

# Column subset for memory efficiency
selected_cols = [
    "BUYER_STATE",
    "BUYER_COUNTY",
    "BUYER_BUS_ACT",
    "BUYER_NAME",
    "TRANSACTION_DATE",
    "MME_Conversion_Factor",
    "CALC_BASE_WT_IN_GM",
]

# %%
for i, chunk in enumerate(
    pd.read_csv(
        filepath,
        chunksize=800_000,
        compression="zip",
        delimiter="\t",
        usecols=selected_cols,
        low_memory=True,
    )
):
    total_records_processed += len(chunk)

    state_selection = chunk[chunk["BUYER_STATE"].isin(selected_states)]
    total_records_kept += len(state_selection)

    state_selection["TOTAL_MME"] = (
        state_selection["MME_Conversion_Factor"]
        * state_selection["CALC_BASE_WT_IN_GM"]
        * 1000
    )

    state_selection["YEAR"] = pd.to_datetime(
        state_selection["TRANSACTION_DATE"]
    ).dt.year

    # Aggregate by county-year, keeping buyer activity info
    grouped = state_selection.groupby(
        ["BUYER_STATE", "BUYER_COUNTY", "YEAR"], as_index=False
    ).agg(
        {
            "TOTAL_MME": "sum",
            "BUYER_BUS_ACT": lambda x: ",".join(sorted(x.unique())),
            "BUYER_NAME": "nunique",
        }
    )
    grouped.rename(columns={"BUYER_NAME": "unique_buyers"}, inplace=True)

    chunks.append(grouped)
    print(
        f"Processed chunk {i+1}: {len(chunk):,} records, kept {len(state_selection):,} from target states"
    )

df = pd.concat(chunks, ignore_index=True)

# Final aggregation across all chunks
df = df.groupby(["BUYER_STATE", "BUYER_COUNTY", "YEAR"], as_index=False).agg(
    {
        "TOTAL_MME": "sum",
        "BUYER_BUS_ACT": lambda x: ",".join(sorted(set(",".join(x).split(",")))),
        "unique_buyers": "sum",
    }
)

print(f"\nProcessing complete:")
print(f"  Total records scanned: {total_records_processed:,}")
print(
    f"  Records from target states: {total_records_kept:,} ({100*total_records_kept/total_records_processed:.1f}%)"
)
print(f"  Final aggregated rows: {len(df):,}")

df.sample(10)
# Out:
# Processed chunk 1: 800,000 records, kept 0 from target states
# Processed chunk 2: 800,000 records, kept 0 from target states
# Processed chunk 2: 800,000 records, kept 0 from target states
# Processed chunk 3: 800,000 records, kept 0 from target states
# Processed chunk 3: 800,000 records, kept 0 from target states
# Processed chunk 4: 800,000 records, kept 0 from target states
# Processed chunk 4: 800,000 records, kept 0 from target states
# Processed chunk 5: 800,000 records, kept 0 from target states
# Processed chunk 5: 800,000 records, kept 0 from target states
# Processed chunk 6: 800,000 records, kept 0 from target states
# Processed chunk 6: 800,000 records, kept 0 from target states
# Processed chunk 7: 800,000 records, kept 0 from target states
# Processed chunk 7: 800,000 records, kept 0 from target states
# Processed chunk 8: 800,000 records, kept 0 from target states
# Processed chunk 8: 800,000 records, kept 0 from target states
# Processed chunk 9: 800,000 records, kept 0 from target states
# Processed chunk 9: 800,000 records, kept 0 from target states
# Processed chunk 10: 800,000 records, kept 0 from target states
# Processed chunk 10: 800,000 records, kept 0 from target states
# Processed chunk 11: 800,000 records, kept 0 from target states
# Processed chunk 11: 800,000 records, kept 0 from target states
# Processed chunk 12: 800,000 records, kept 0 from target states
# Processed chunk 12: 800,000 records, kept 0 from target states
# Processed chunk 13: 800,000 records, kept 0 from target states
# Processed chunk 13: 800,000 records, kept 0 from target states
# Processed chunk 14: 800,000 records, kept 0 from target states
# Processed chunk 14: 800,000 records, kept 0 from target states
# Processed chunk 15: 800,000 records, kept 0 from target states
# Processed chunk 15: 800,000 records, kept 0 from target states
# Processed chunk 16: 800,000 records, kept 0 from target states
# Processed chunk 16: 800,000 records, kept 0 from target states
# Processed chunk 17: 800,000 records, kept 0 from target states
# Processed chunk 17: 800,000 records, kept 0 from target states
# Processed chunk 18: 800,000 records, kept 0 from target states
# Processed chunk 18: 800,000 records, kept 0 from target states
# Processed chunk 19: 800,000 records, kept 0 from target states
# Processed chunk 19: 800,000 records, kept 0 from target states
# Processed chunk 20: 800,000 records, kept 0 from target states
# Processed chunk 20: 800,000 records, kept 0 from target states
# Processed chunk 21: 800,000 records, kept 0 from target states
# Processed chunk 21: 800,000 records, kept 0 from target states
# Processed chunk 22: 800,000 records, kept 600,000 from target states
# Processed chunk 22: 800,000 records, kept 600,000 from target states
# Processed chunk 23: 800,000 records, kept 400,000 from target states
# Processed chunk 23: 800,000 records, kept 400,000 from target states
# Processed chunk 24: 800,000 records, kept 0 from target states
# Processed chunk 24: 800,000 records, kept 0 from target states
# Processed chunk 25: 800,000 records, kept 0 from target states
# Processed chunk 25: 800,000 records, kept 0 from target states
# Processed chunk 26: 800,000 records, kept 800,000 from target states
# Processed chunk 26: 800,000 records, kept 800,000 from target states
# Processed chunk 27: 800,000 records, kept 200,000 from target states
# Processed chunk 27: 800,000 records, kept 200,000 from target states
# Processed chunk 28: 800,000 records, kept 0 from target states
# Processed chunk 28: 800,000 records, kept 0 from target states
# Processed chunk 29: 800,000 records, kept 0 from target states
# Processed chunk 29: 800,000 records, kept 0 from target states
# Processed chunk 30: 800,000 records, kept 0 from target states
# Processed chunk 30: 800,000 records, kept 0 from target states
# Processed chunk 31: 800,000 records, kept 800,000 from target states
# Processed chunk 31: 800,000 records, kept 800,000 from target states
# Processed chunk 32: 800,000 records, kept 800,000 from target states
# Processed chunk 32: 800,000 records, kept 800,000 from target states
# Processed chunk 33: 800,000 records, kept 800,000 from target states
# Processed chunk 33: 800,000 records, kept 800,000 from target states
# Processed chunk 34: 800,000 records, kept 600,000 from target states
# Processed chunk 34: 800,000 records, kept 600,000 from target states
# Processed chunk 35: 800,000 records, kept 0 from target states
# Processed chunk 35: 800,000 records, kept 0 from target states
# Processed chunk 36: 800,000 records, kept 0 from target states
# Processed chunk 36: 800,000 records, kept 0 from target states
# Processed chunk 37: 800,000 records, kept 0 from target states
# Processed chunk 37: 800,000 records, kept 0 from target states
# Processed chunk 38: 800,000 records, kept 0 from target states
# Processed chunk 38: 800,000 records, kept 0 from target states
# Processed chunk 39: 800,000 records, kept 0 from target states
# Processed chunk 39: 800,000 records, kept 0 from target states
# Processed chunk 40: 800,000 records, kept 0 from target states
# Processed chunk 40: 800,000 records, kept 0 from target states
# Processed chunk 41: 800,000 records, kept 0 from target states
# Processed chunk 41: 800,000 records, kept 0 from target states
# Processed chunk 42: 800,000 records, kept 0 from target states
# Processed chunk 42: 800,000 records, kept 0 from target states
# Processed chunk 43: 800,000 records, kept 0 from target states
# Processed chunk 43: 800,000 records, kept 0 from target states
# Processed chunk 44: 800,000 records, kept 200,000 from target states
# Processed chunk 44: 800,000 records, kept 200,000 from target states
# Processed chunk 45: 800,000 records, kept 800,000 from target states
# Processed chunk 45: 800,000 records, kept 800,000 from target states
# Processed chunk 46: 800,000 records, kept 0 from target states
# Processed chunk 46: 800,000 records, kept 0 from target states
# Processed chunk 47: 800,000 records, kept 0 from target states
# Processed chunk 47: 800,000 records, kept 0 from target states
# Processed chunk 48: 800,000 records, kept 0 from target states
# Processed chunk 48: 800,000 records, kept 0 from target states
# Processed chunk 49: 800,000 records, kept 0 from target states
# Processed chunk 49: 800,000 records, kept 0 from target states
# Processed chunk 50: 800,000 records, kept 0 from target states
# Processed chunk 50: 800,000 records, kept 0 from target states
# Processed chunk 51: 800,000 records, kept 0 from target states
# Processed chunk 51: 800,000 records, kept 0 from target states
# Processed chunk 52: 800,000 records, kept 0 from target states
# Processed chunk 52: 800,000 records, kept 0 from target states
# Processed chunk 53: 800,000 records, kept 0 from target states
# Processed chunk 53: 800,000 records, kept 0 from target states
# Processed chunk 54: 800,000 records, kept 0 from target states
# Processed chunk 54: 800,000 records, kept 0 from target states
# Processed chunk 55: 800,000 records, kept 0 from target states
# Processed chunk 55: 800,000 records, kept 0 from target states
# Processed chunk 56: 800,000 records, kept 0 from target states
# Processed chunk 56: 800,000 records, kept 0 from target states
# Processed chunk 57: 800,000 records, kept 0 from target states
# Processed chunk 57: 800,000 records, kept 0 from target states
# Processed chunk 58: 800,000 records, kept 0 from target states
# Processed chunk 58: 800,000 records, kept 0 from target states
# Processed chunk 59: 800,000 records, kept 0 from target states
# Processed chunk 59: 800,000 records, kept 0 from target states
# Processed chunk 60: 800,000 records, kept 0 from target states
# Processed chunk 60: 800,000 records, kept 0 from target states
# Processed chunk 61: 800,000 records, kept 0 from target states
# Processed chunk 61: 800,000 records, kept 0 from target states
# Processed chunk 62: 800,000 records, kept 0 from target states
# Processed chunk 62: 800,000 records, kept 0 from target states
# Processed chunk 63: 800,000 records, kept 0 from target states
# Processed chunk 63: 800,000 records, kept 0 from target states
# Processed chunk 64: 800,000 records, kept 0 from target states
# Processed chunk 64: 800,000 records, kept 0 from target states
# Processed chunk 65: 800,000 records, kept 0 from target states
# Processed chunk 65: 800,000 records, kept 0 from target states
# Processed chunk 66: 800,000 records, kept 0 from target states
# Processed chunk 66: 800,000 records, kept 0 from target states
# Processed chunk 67: 800,000 records, kept 0 from target states
# Processed chunk 67: 800,000 records, kept 0 from target states
# Processed chunk 68: 800,000 records, kept 400,000 from target states
# Processed chunk 68: 800,000 records, kept 400,000 from target states
# Processed chunk 69: 800,000 records, kept 600,000 from target states
# Processed chunk 69: 800,000 records, kept 600,000 from target states
# Processed chunk 70: 800,000 records, kept 0 from target states
# Processed chunk 70: 800,000 records, kept 0 from target states
# Processed chunk 71: 800,000 records, kept 0 from target states
# Processed chunk 71: 800,000 records, kept 0 from target states
# Processed chunk 72: 800,000 records, kept 0 from target states
# Processed chunk 72: 800,000 records, kept 0 from target states
# Processed chunk 73: 800,000 records, kept 0 from target states
# Processed chunk 73: 800,000 records, kept 0 from target states
# Processed chunk 74: 800,000 records, kept 200,000 from target states
# Processed chunk 74: 800,000 records, kept 200,000 from target states
# Processed chunk 75: 800,000 records, kept 800,000 from target states
# Processed chunk 75: 800,000 records, kept 800,000 from target states
# Processed chunk 76: 800,000 records, kept 0 from target states
# Processed chunk 76: 800,000 records, kept 0 from target states
# Processed chunk 77: 800,000 records, kept 0 from target states
# Processed chunk 77: 800,000 records, kept 0 from target states
# Processed chunk 78: 800,000 records, kept 400,000 from target states
# Processed chunk 78: 800,000 records, kept 400,000 from target states
# Processed chunk 79: 800,000 records, kept 600,000 from target states
# Processed chunk 79: 800,000 records, kept 600,000 from target states
# Processed chunk 80: 800,000 records, kept 0 from target states
# Processed chunk 80: 800,000 records, kept 0 from target states
# Processed chunk 81: 800,000 records, kept 0 from target states
# Processed chunk 81: 800,000 records, kept 0 from target states
# Processed chunk 82: 800,000 records, kept 0 from target states
# Processed chunk 82: 800,000 records, kept 0 from target states
# Processed chunk 83: 800,000 records, kept 0 from target states
# Processed chunk 83: 800,000 records, kept 0 from target states
# Processed chunk 84: 800,000 records, kept 0 from target states
# Processed chunk 84: 800,000 records, kept 0 from target states
# Processed chunk 85: 800,000 records, kept 0 from target states
# Processed chunk 85: 800,000 records, kept 0 from target states
# Processed chunk 86: 800,000 records, kept 0 from target states
# Processed chunk 86: 800,000 records, kept 0 from target states
# Processed chunk 87: 800,000 records, kept 0 from target states
# Processed chunk 87: 800,000 records, kept 0 from target states
# Processed chunk 88: 800,000 records, kept 0 from target states
# Processed chunk 88: 800,000 records, kept 0 from target states
# Processed chunk 89: 800,000 records, kept 0 from target states
# Processed chunk 89: 800,000 records, kept 0 from target states
# Processed chunk 90: 800,000 records, kept 0 from target states
# Processed chunk 90: 800,000 records, kept 0 from target states
# Processed chunk 91: 800,000 records, kept 800,000 from target states
# Processed chunk 91: 800,000 records, kept 800,000 from target states
# Processed chunk 92: 800,000 records, kept 200,000 from target states
# Processed chunk 92: 800,000 records, kept 200,000 from target states
# Processed chunk 93: 800,000 records, kept 0 from target states
# Processed chunk 93: 800,000 records, kept 0 from target states
# Processed chunk 94: 800,000 records, kept 0 from target states
# Processed chunk 94: 800,000 records, kept 0 from target states
# Processed chunk 95: 800,000 records, kept 0 from target states
# Processed chunk 95: 800,000 records, kept 0 from target states
# Processed chunk 96: 800,000 records, kept 0 from target states
# Processed chunk 96: 800,000 records, kept 0 from target states
# Processed chunk 97: 800,000 records, kept 0 from target states
# Processed chunk 97: 800,000 records, kept 0 from target states
# Processed chunk 98: 800,000 records, kept 0 from target states
# Processed chunk 98: 800,000 records, kept 0 from target states
# Processed chunk 99: 800,000 records, kept 0 from target states
# Processed chunk 99: 800,000 records, kept 0 from target states
# Processed chunk 100: 800,000 records, kept 0 from target states
# Processed chunk 100: 800,000 records, kept 0 from target states
# Processed chunk 101: 800,000 records, kept 0 from target states
# Processed chunk 101: 800,000 records, kept 0 from target states
# Processed chunk 102: 800,000 records, kept 0 from target states
# Processed chunk 102: 800,000 records, kept 0 from target states
# Processed chunk 103: 800,000 records, kept 400,000 from target states
# Processed chunk 103: 800,000 records, kept 400,000 from target states
# Processed chunk 104: 800,000 records, kept 800,000 from target states
# Processed chunk 104: 800,000 records, kept 800,000 from target states
# Processed chunk 105: 800,000 records, kept 800,000 from target states
# Processed chunk 105: 800,000 records, kept 800,000 from target states
# Processed chunk 106: 800,000 records, kept 0 from target states
# Processed chunk 106: 800,000 records, kept 0 from target states
# Processed chunk 107: 800,000 records, kept 600,000 from target states
# Processed chunk 107: 800,000 records, kept 600,000 from target states
# Processed chunk 108: 800,000 records, kept 400,000 from target states
# Processed chunk 108: 800,000 records, kept 400,000 from target states
# Processed chunk 109: 800,000 records, kept 200,000 from target states
# Processed chunk 109: 800,000 records, kept 200,000 from target states
# Processed chunk 110: 800,000 records, kept 800,000 from target states
# Processed chunk 110: 800,000 records, kept 800,000 from target states
# Processed chunk 111: 800,000 records, kept 800,000 from target states
# Processed chunk 111: 800,000 records, kept 800,000 from target states
# Processed chunk 112: 800,000 records, kept 800,000 from target states
# Processed chunk 112: 800,000 records, kept 800,000 from target states
# Processed chunk 113: 800,000 records, kept 400,000 from target states
# Processed chunk 113: 800,000 records, kept 400,000 from target states
# Processed chunk 114: 800,000 records, kept 200,000 from target states
# Processed chunk 114: 800,000 records, kept 200,000 from target states
# Processed chunk 115: 800,000 records, kept 800,000 from target states
# Processed chunk 115: 800,000 records, kept 800,000 from target states
# Processed chunk 116: 800,000 records, kept 0 from target states
# Processed chunk 116: 800,000 records, kept 0 from target states
# Processed chunk 117: 800,000 records, kept 600,000 from target states
# Processed chunk 117: 800,000 records, kept 600,000 from target states
# Processed chunk 118: 800,000 records, kept 400,000 from target states
# Processed chunk 118: 800,000 records, kept 400,000 from target states
# Processed chunk 119: 800,000 records, kept 200,000 from target states
# Processed chunk 119: 800,000 records, kept 200,000 from target states
# Processed chunk 120: 800,000 records, kept 800,000 from target states
# Processed chunk 120: 800,000 records, kept 800,000 from target states
# Processed chunk 121: 800,000 records, kept 0 from target states
# Processed chunk 121: 800,000 records, kept 0 from target states
# Processed chunk 122: 800,000 records, kept 600,000 from target states
# Processed chunk 122: 800,000 records, kept 600,000 from target states
# Processed chunk 123: 800,000 records, kept 800,000 from target states
# Processed chunk 123: 800,000 records, kept 800,000 from target states
# Processed chunk 124: 800,000 records, kept 800,000 from target states
# Processed chunk 124: 800,000 records, kept 800,000 from target states
# Processed chunk 125: 800,000 records, kept 800,000 from target states
# Processed chunk 125: 800,000 records, kept 800,000 from target states
# Processed chunk 126: 800,000 records, kept 0 from target states
# Processed chunk 126: 800,000 records, kept 0 from target states
# Processed chunk 127: 800,000 records, kept 600,000 from target states
# Processed chunk 127: 800,000 records, kept 600,000 from target states
# Processed chunk 128: 800,000 records, kept 800,000 from target states
# Processed chunk 128: 800,000 records, kept 800,000 from target states
# Processed chunk 129: 800,000 records, kept 800,000 from target states
# Processed chunk 129: 800,000 records, kept 800,000 from target states
# Processed chunk 130: 800,000 records, kept 800,000 from target states
# Processed chunk 130: 800,000 records, kept 800,000 from target states
# Processed chunk 131: 800,000 records, kept 0 from target states
# Processed chunk 131: 800,000 records, kept 0 from target states
# Processed chunk 132: 800,000 records, kept 600,000 from target states
# Processed chunk 132: 800,000 records, kept 600,000 from target states
# Processed chunk 133: 800,000 records, kept 800,000 from target states
# Processed chunk 133: 800,000 records, kept 800,000 from target states
# Processed chunk 134: 800,000 records, kept 800,000 from target states
# Processed chunk 134: 800,000 records, kept 800,000 from target states
# Processed chunk 135: 800,000 records, kept 800,000 from target states
# Processed chunk 135: 800,000 records, kept 800,000 from target states
# Processed chunk 136: 800,000 records, kept 800,000 from target states
# Processed chunk 136: 800,000 records, kept 800,000 from target states
# Processed chunk 137: 800,000 records, kept 200,000 from target states
# Processed chunk 137: 800,000 records, kept 200,000 from target states
# Processed chunk 138: 800,000 records, kept 400,000 from target states
# Processed chunk 138: 800,000 records, kept 400,000 from target states
# Processed chunk 139: 800,000 records, kept 600,000 from target states
# Processed chunk 139: 800,000 records, kept 600,000 from target states
# Processed chunk 140: 800,000 records, kept 0 from target states
# Processed chunk 140: 800,000 records, kept 0 from target states
# Processed chunk 141: 800,000 records, kept 0 from target states
# Processed chunk 141: 800,000 records, kept 0 from target states
# Processed chunk 142: 800,000 records, kept 600,000 from target states
# Processed chunk 142: 800,000 records, kept 600,000 from target states
# Processed chunk 143: 800,000 records, kept 800,000 from target states
# Processed chunk 143: 800,000 records, kept 800,000 from target states
# Processed chunk 144: 800,000 records, kept 600,000 from target states
# Processed chunk 144: 800,000 records, kept 600,000 from target states
# Processed chunk 145: 800,000 records, kept 0 from target states
# Processed chunk 145: 800,000 records, kept 0 from target states
# Processed chunk 146: 800,000 records, kept 0 from target states
# Processed chunk 146: 800,000 records, kept 0 from target states
# Processed chunk 147: 800,000 records, kept 0 from target states
# Processed chunk 147: 800,000 records, kept 0 from target states
# Processed chunk 148: 800,000 records, kept 0 from target states
# Processed chunk 148: 800,000 records, kept 0 from target states
# Processed chunk 149: 800,000 records, kept 200,000 from target states
# Processed chunk 149: 800,000 records, kept 200,000 from target states
# Processed chunk 150: 800,000 records, kept 800,000 from target states
# Processed chunk 150: 800,000 records, kept 800,000 from target states
# Processed chunk 151: 800,000 records, kept 0 from target states
# Processed chunk 151: 800,000 records, kept 0 from target states
# Processed chunk 152: 800,000 records, kept 600,000 from target states
# Processed chunk 152: 800,000 records, kept 600,000 from target states
# Processed chunk 153: 800,000 records, kept 400,000 from target states
# Processed chunk 153: 800,000 records, kept 400,000 from target states
# Processed chunk 154: 800,000 records, kept 0 from target states
# Processed chunk 154: 800,000 records, kept 0 from target states
# Processed chunk 155: 800,000 records, kept 0 from target states
# Processed chunk 155: 800,000 records, kept 0 from target states
# Processed chunk 156: 800,000 records, kept 0 from target states
# Processed chunk 156: 800,000 records, kept 0 from target states
# Processed chunk 157: 800,000 records, kept 0 from target states
# Processed chunk 157: 800,000 records, kept 0 from target states
# Processed chunk 158: 800,000 records, kept 400,000 from target states
# Processed chunk 158: 800,000 records, kept 400,000 from target states
# Processed chunk 159: 800,000 records, kept 600,000 from target states
# Processed chunk 159: 800,000 records, kept 600,000 from target states
# Processed chunk 160: 800,000 records, kept 0 from target states
# Processed chunk 160: 800,000 records, kept 0 from target states
# Processed chunk 161: 800,000 records, kept 0 from target states
# Processed chunk 161: 800,000 records, kept 0 from target states
# Processed chunk 162: 800,000 records, kept 0 from target states
# Processed chunk 162: 800,000 records, kept 0 from target states
# Processed chunk 163: 800,000 records, kept 0 from target states
# Processed chunk 163: 800,000 records, kept 0 from target states
# Processed chunk 164: 800,000 records, kept 0 from target states
# Processed chunk 164: 800,000 records, kept 0 from target states
# Processed chunk 165: 800,000 records, kept 0 from target states
# Processed chunk 165: 800,000 records, kept 0 from target states
# Processed chunk 166: 800,000 records, kept 0 from target states
# Processed chunk 166: 800,000 records, kept 0 from target states
# Processed chunk 167: 800,000 records, kept 0 from target states
# Processed chunk 167: 800,000 records, kept 0 from target states
# Processed chunk 168: 800,000 records, kept 0 from target states
# Processed chunk 168: 800,000 records, kept 0 from target states
# Processed chunk 169: 800,000 records, kept 0 from target states
# Processed chunk 169: 800,000 records, kept 0 from target states
# Processed chunk 170: 800,000 records, kept 0 from target states
# Processed chunk 170: 800,000 records, kept 0 from target states
# Processed chunk 171: 800,000 records, kept 0 from target states
# Processed chunk 171: 800,000 records, kept 0 from target states
# Processed chunk 172: 800,000 records, kept 0 from target states
# Processed chunk 172: 800,000 records, kept 0 from target states
# Processed chunk 173: 800,000 records, kept 0 from target states
# Processed chunk 173: 800,000 records, kept 0 from target states
# Processed chunk 174: 800,000 records, kept 0 from target states
# Processed chunk 174: 800,000 records, kept 0 from target states
# Processed chunk 175: 800,000 records, kept 0 from target states
# Processed chunk 175: 800,000 records, kept 0 from target states
# Processed chunk 176: 800,000 records, kept 0 from target states
# Processed chunk 176: 800,000 records, kept 0 from target states
# Processed chunk 177: 800,000 records, kept 0 from target states
# Processed chunk 177: 800,000 records, kept 0 from target states
# Processed chunk 178: 800,000 records, kept 0 from target states
# Processed chunk 178: 800,000 records, kept 0 from target states
# Processed chunk 179: 800,000 records, kept 200,000 from target states
# Processed chunk 179: 800,000 records, kept 200,000 from target states
# Processed chunk 180: 800,000 records, kept 665,827 from target states
# Processed chunk 180: 800,000 records, kept 665,827 from target states
# Processed chunk 181: 800,000 records, kept 0 from target states
# Processed chunk 181: 800,000 records, kept 0 from target states
# Processed chunk 182: 800,000 records, kept 0 from target states
# Processed chunk 182: 800,000 records, kept 0 from target states
# Processed chunk 183: 800,000 records, kept 0 from target states
# Processed chunk 183: 800,000 records, kept 0 from target states
# Processed chunk 184: 800,000 records, kept 0 from target states
# Processed chunk 184: 800,000 records, kept 0 from target states
# Processed chunk 185: 800,000 records, kept 0 from target states
# Processed chunk 185: 800,000 records, kept 0 from target states
# Processed chunk 186: 800,000 records, kept 0 from target states
# Processed chunk 186: 800,000 records, kept 0 from target states
# Processed chunk 187: 800,000 records, kept 0 from target states
# Processed chunk 187: 800,000 records, kept 0 from target states
# Processed chunk 188: 800,000 records, kept 400,000 from target states
# Processed chunk 188: 800,000 records, kept 400,000 from target states
# Processed chunk 189: 800,000 records, kept 600,000 from target states
# Processed chunk 189: 800,000 records, kept 600,000 from target states
# Processed chunk 190: 800,000 records, kept 0 from target states
# Processed chunk 190: 800,000 records, kept 0 from target states
# Processed chunk 191: 800,000 records, kept 0 from target states
# Processed chunk 191: 800,000 records, kept 0 from target states
# Processed chunk 192: 800,000 records, kept 0 from target states
# Processed chunk 192: 800,000 records, kept 0 from target states
# Processed chunk 193: 800,000 records, kept 0 from target states
# Processed chunk 193: 800,000 records, kept 0 from target states
# Processed chunk 194: 800,000 records, kept 0 from target states
# Processed chunk 194: 800,000 records, kept 0 from target states
# Processed chunk 195: 800,000 records, kept 0 from target states
# Processed chunk 195: 800,000 records, kept 0 from target states
# Processed chunk 196: 800,000 records, kept 0 from target states
# Processed chunk 196: 800,000 records, kept 0 from target states
# Processed chunk 197: 800,000 records, kept 0 from target states
# Processed chunk 197: 800,000 records, kept 0 from target states
# Processed chunk 198: 800,000 records, kept 0 from target states
# Processed chunk 198: 800,000 records, kept 0 from target states
# Processed chunk 199: 800,000 records, kept 0 from target states
# Processed chunk 199: 800,000 records, kept 0 from target states
# Processed chunk 200: 800,000 records, kept 39,954 from target states
# Processed chunk 200: 800,000 records, kept 39,954 from target states
# Processed chunk 201: 800,000 records, kept 0 from target states
# Processed chunk 201: 800,000 records, kept 0 from target states
# Processed chunk 202: 800,000 records, kept 0 from target states
# Processed chunk 202: 800,000 records, kept 0 from target states
# Processed chunk 203: 800,000 records, kept 0 from target states
# Processed chunk 203: 800,000 records, kept 0 from target states
# Processed chunk 204: 800,000 records, kept 200,000 from target states
# Processed chunk 204: 800,000 records, kept 200,000 from target states
# Processed chunk 205: 800,000 records, kept 800,000 from target states
# Processed chunk 205: 800,000 records, kept 800,000 from target states
# Processed chunk 206: 800,000 records, kept 0 from target states
# Processed chunk 206: 800,000 records, kept 0 from target states
# Processed chunk 207: 800,000 records, kept 0 from target states
# Processed chunk 207: 800,000 records, kept 0 from target states
# Processed chunk 208: 800,000 records, kept 0 from target states
# Processed chunk 208: 800,000 records, kept 0 from target states
# Processed chunk 209: 800,000 records, kept 0 from target states
# Processed chunk 209: 800,000 records, kept 0 from target states
# Processed chunk 210: 800,000 records, kept 0 from target states
# Processed chunk 210: 800,000 records, kept 0 from target states
# Processed chunk 211: 800,000 records, kept 800,000 from target states
# Processed chunk 211: 800,000 records, kept 800,000 from target states
# Processed chunk 212: 800,000 records, kept 200,000 from target states
# Processed chunk 212: 800,000 records, kept 200,000 from target states
# Processed chunk 213: 800,000 records, kept 400,000 from target states
# Processed chunk 213: 800,000 records, kept 400,000 from target states
# Processed chunk 214: 800,000 records, kept 800,000 from target states
# Processed chunk 214: 800,000 records, kept 800,000 from target states
# Processed chunk 215: 800,000 records, kept 800,000 from target states
# Processed chunk 215: 800,000 records, kept 800,000 from target states
# Processed chunk 216: 800,000 records, kept 0 from target states
# Processed chunk 216: 800,000 records, kept 0 from target states
# Processed chunk 217: 800,000 records, kept 600,000 from target states
# Processed chunk 217: 800,000 records, kept 600,000 from target states
# Processed chunk 218: 800,000 records, kept 800,000 from target states
# Processed chunk 218: 800,000 records, kept 800,000 from target states
# Processed chunk 219: 800,000 records, kept 600,000 from target states
# Processed chunk 219: 800,000 records, kept 600,000 from target states
# Processed chunk 220: 800,000 records, kept 0 from target states
# Processed chunk 220: 800,000 records, kept 0 from target states
# Processed chunk 221: 800,000 records, kept 0 from target states
# Processed chunk 221: 800,000 records, kept 0 from target states
# Processed chunk 222: 800,000 records, kept 0 from target states
# Processed chunk 222: 800,000 records, kept 0 from target states
# Processed chunk 223: 800,000 records, kept 0 from target states
# Processed chunk 223: 800,000 records, kept 0 from target states
# Processed chunk 224: 800,000 records, kept 0 from target states
# Processed chunk 224: 800,000 records, kept 0 from target states
# Processed chunk 225: 800,000 records, kept 0 from target states
# Processed chunk 225: 800,000 records, kept 0 from target states
# Processed chunk 226: 800,000 records, kept 0 from target states
# Processed chunk 226: 800,000 records, kept 0 from target states
# Processed chunk 227: 800,000 records, kept 0 from target states
# Processed chunk 227: 800,000 records, kept 0 from target states
# Processed chunk 228: 800,000 records, kept 0 from target states
# Processed chunk 228: 800,000 records, kept 0 from target states
# Processed chunk 229: 800,000 records, kept 0 from target states
# Processed chunk 229: 800,000 records, kept 0 from target states
# Processed chunk 230: 800,000 records, kept 0 from target states
# Processed chunk 230: 800,000 records, kept 0 from target states
# Processed chunk 231: 800,000 records, kept 0 from target states
# Processed chunk 231: 800,000 records, kept 0 from target states
# Processed chunk 232: 800,000 records, kept 0 from target states
# Processed chunk 232: 800,000 records, kept 0 from target states
# Processed chunk 233: 800,000 records, kept 0 from target states
# Processed chunk 233: 800,000 records, kept 0 from target states
# Processed chunk 234: 800,000 records, kept 0 from target states
# Processed chunk 234: 800,000 records, kept 0 from target states
# Processed chunk 235: 800,000 records, kept 0 from target states
# Processed chunk 235: 800,000 records, kept 0 from target states
# Processed chunk 236: 800,000 records, kept 0 from target states
# Processed chunk 237: 800,000 records, kept 600,000 from target states
# Processed chunk 238: 800,000 records, kept 301,547 from target states
# Processed chunk 239: 800,000 records, kept 0 from target states
# Processed chunk 240: 800,000 records, kept 0 from target states
# Processed chunk 241: 800,000 records, kept 0 from target states
# Processed chunk 242: 800,000 records, kept 0 from target states
# Processed chunk 243: 800,000 records, kept 0 from target states
# Processed chunk 244: 800,000 records, kept 213,169 from target states
# Processed chunk 245: 800,000 records, kept 0 from target states
# Processed chunk 246: 800,000 records, kept 800,000 from target states
# Processed chunk 247: 800,000 records, kept 200,000 from target states
# Processed chunk 248: 800,000 records, kept 0 from target states
# Processed chunk 249: 800,000 records, kept 0 from target states
# Processed chunk 250: 800,000 records, kept 0 from target states
# Processed chunk 251: 800,000 records, kept 0 from target states
# Processed chunk 252: 800,000 records, kept 0 from target states
# Processed chunk 253: 800,000 records, kept 0 from target states
# Processed chunk 254: 800,000 records, kept 0 from target states
# Processed chunk 255: 800,000 records, kept 0 from target states
# Processed chunk 256: 800,000 records, kept 0 from target states
# Processed chunk 257: 800,000 records, kept 0 from target states
# Processed chunk 258: 800,000 records, kept 0 from target states
# Processed chunk 259: 800,000 records, kept 200,000 from target states
# Processed chunk 260: 800,000 records, kept 800,000 from target states
# Processed chunk 261: 800,000 records, kept 800,000 from target states
# Processed chunk 262: 800,000 records, kept 800,000 from target states
# Processed chunk 263: 800,000 records, kept 400,000 from target states
# Processed chunk 264: 800,000 records, kept 0 from target states
# Processed chunk 265: 800,000 records, kept 0 from target states
# Processed chunk 266: 800,000 records, kept 0 from target states
# Processed chunk 267: 800,000 records, kept 0 from target states
# Processed chunk 268: 800,000 records, kept 0 from target states
# Processed chunk 269: 800,000 records, kept 0 from target states
# Processed chunk 270: 800,000 records, kept 0 from target states
# Processed chunk 271: 800,000 records, kept 0 from target states
# Processed chunk 272: 800,000 records, kept 0 from target states
# Processed chunk 273: 800,000 records, kept 0 from target states
# Processed chunk 274: 800,000 records, kept 0 from target states
# Processed chunk 275: 800,000 records, kept 0 from target states
# Processed chunk 276: 800,000 records, kept 0 from target states
# Processed chunk 277: 800,000 records, kept 0 from target states
# Processed chunk 278: 800,000 records, kept 0 from target states
# Processed chunk 279: 800,000 records, kept 0 from target states
# Processed chunk 280: 800,000 records, kept 0 from target states
# Processed chunk 281: 800,000 records, kept 0 from target states
# Processed chunk 282: 800,000 records, kept 0 from target states
# Processed chunk 283: 800,000 records, kept 0 from target states
# Processed chunk 284: 800,000 records, kept 0 from target states
# Processed chunk 285: 800,000 records, kept 0 from target states
# Processed chunk 286: 800,000 records, kept 800,000 from target states
# Processed chunk 287: 800,000 records, kept 200,000 from target states
# Processed chunk 288: 800,000 records, kept 400,000 from target states
# Processed chunk 289: 800,000 records, kept 600,000 from target states
# Processed chunk 290: 800,000 records, kept 0 from target states
# Processed chunk 291: 800,000 records, kept 0 from target states
# Processed chunk 292: 800,000 records, kept 600,000 from target states
# Processed chunk 293: 800,000 records, kept 117,298 from target states
# Processed chunk 294: 800,000 records, kept 0 from target states
# Processed chunk 295: 800,000 records, kept 0 from target states
# Processed chunk 296: 800,000 records, kept 0 from target states
# Processed chunk 297: 800,000 records, kept 0 from target states
# Processed chunk 298: 800,000 records, kept 0 from target states
# Processed chunk 299: 800,000 records, kept 0 from target states
# Processed chunk 300: 800,000 records, kept 0 from target states
# Processed chunk 301: 800,000 records, kept 0 from target states
# Processed chunk 302: 800,000 records, kept 0 from target states
# Processed chunk 303: 800,000 records, kept 297,521 from target states
# Processed chunk 304: 800,000 records, kept 200,000 from target states
# Processed chunk 305: 800,000 records, kept 800,000 from target states
# Processed chunk 306: 800,000 records, kept 0 from target states
# Processed chunk 307: 800,000 records, kept 0 from target states
# Processed chunk 308: 800,000 records, kept 0 from target states
# Processed chunk 309: 800,000 records, kept 0 from target states
# Processed chunk 310: 800,000 records, kept 0 from target states
# Processed chunk 311: 800,000 records, kept 573,000 from target states
# Processed chunk 312: 800,000 records, kept 600,000 from target states
# Processed chunk 313: 800,000 records, kept 400,000 from target states
# Processed chunk 314: 800,000 records, kept 0 from target states
# Processed chunk 315: 800,000 records, kept 0 from target states
# Processed chunk 316: 800,000 records, kept 0 from target states
# Processed chunk 317: 800,000 records, kept 0 from target states
# Processed chunk 318: 800,000 records, kept 0 from target states
# Processed chunk 319: 800,000 records, kept 0 from target states
# Processed chunk 320: 800,000 records, kept 0 from target states
# Processed chunk 321: 800,000 records, kept 0 from target states
# Processed chunk 322: 800,000 records, kept 600,000 from target states
# Processed chunk 323: 800,000 records, kept 126,639 from target states
# Processed chunk 324: 800,000 records, kept 0 from target states
# Processed chunk 325: 800,000 records, kept 0 from target states
# Processed chunk 326: 800,000 records, kept 109,580 from target states
# Processed chunk 327: 800,000 records, kept 200,000 from target states
# Processed chunk 328: 800,000 records, kept 0 from target states
# Processed chunk 329: 800,000 records, kept 0 from target states
# Processed chunk 330: 800,000 records, kept 0 from target states
# Processed chunk 331: 800,000 records, kept 0 from target states
# Processed chunk 332: 800,000 records, kept 0 from target states
# Processed chunk 333: 800,000 records, kept 0 from target states
# Processed chunk 334: 800,000 records, kept 0 from target states
# Processed chunk 335: 800,000 records, kept 0 from target states
# Processed chunk 336: 800,000 records, kept 0 from target states
# Processed chunk 337: 800,000 records, kept 0 from target states
# Processed chunk 338: 800,000 records, kept 0 from target states
# Processed chunk 339: 800,000 records, kept 0 from target states
# Processed chunk 340: 800,000 records, kept 0 from target states
# Processed chunk 341: 800,000 records, kept 0 from target states
# Processed chunk 342: 800,000 records, kept 0 from target states
# Processed chunk 343: 800,000 records, kept 0 from target states
# Processed chunk 344: 800,000 records, kept 545,547 from target states
# Processed chunk 345: 800,000 records, kept 0 from target states
# Processed chunk 346: 800,000 records, kept 0 from target states
# Processed chunk 347: 800,000 records, kept 0 from target states
# Processed chunk 348: 800,000 records, kept 0 from target states
# Processed chunk 349: 800,000 records, kept 0 from target states
# Processed chunk 350: 800,000 records, kept 0 from target states
# Processed chunk 351: 800,000 records, kept 374,501 from target states
# Processed chunk 352: 800,000 records, kept 0 from target states
# Processed chunk 353: 800,000 records, kept 0 from target states
# Processed chunk 354: 800,000 records, kept 0 from target states
# Processed chunk 355: 800,000 records, kept 0 from target states
# Processed chunk 356: 800,000 records, kept 0 from target states
# Processed chunk 357: 800,000 records, kept 0 from target states
# Processed chunk 358: 800,000 records, kept 0 from target states
# Processed chunk 359: 800,000 records, kept 0 from target states
# Processed chunk 360: 800,000 records, kept 0 from target states
# Processed chunk 361: 800,000 records, kept 0 from target states
# Processed chunk 362: 800,000 records, kept 0 from target states
# Processed chunk 363: 800,000 records, kept 0 from target states
# Processed chunk 364: 800,000 records, kept 0 from target states
# Processed chunk 365: 800,000 records, kept 0 from target states
# Processed chunk 366: 800,000 records, kept 0 from target states
# Processed chunk 367: 800,000 records, kept 0 from target states
# Processed chunk 368: 800,000 records, kept 0 from target states
# Processed chunk 369: 800,000 records, kept 0 from target states
# Processed chunk 370: 800,000 records, kept 0 from target states
# Processed chunk 371: 800,000 records, kept 0 from target states
# Processed chunk 372: 800,000 records, kept 0 from target states
# Processed chunk 373: 800,000 records, kept 0 from target states
# Processed chunk 374: 800,000 records, kept 0 from target states
# Processed chunk 375: 800,000 records, kept 0 from target states
# Processed chunk 376: 800,000 records, kept 629,687 from target states
# Processed chunk 377: 800,000 records, kept 800,000 from target states
# Processed chunk 378: 800,000 records, kept 308,394 from target states
# Processed chunk 379: 800,000 records, kept 291,606 from target states
# Processed chunk 380: 800,000 records, kept 708,394 from target states
# Processed chunk 381: 800,000 records, kept 0 from target states
# Processed chunk 382: 800,000 records, kept 691,606 from target states
# Processed chunk 383: 800,000 records, kept 800,000 from target states
# Processed chunk 384: 800,000 records, kept 800,000 from target states
# Processed chunk 385: 800,000 records, kept 708,394 from target states
# Processed chunk 386: 800,000 records, kept 0 from target states
# Processed chunk 387: 800,000 records, kept 0 from target states
# Processed chunk 388: 800,000 records, kept 396,244 from target states
# Processed chunk 389: 800,000 records, kept 508,394 from target states
# Processed chunk 390: 800,000 records, kept 91,606 from target states
# Processed chunk 391: 800,000 records, kept 800,000 from target states
# Processed chunk 392: 800,000 records, kept 108,394 from target states
# Processed chunk 393: 800,000 records, kept 0 from target states
# Processed chunk 394: 800,000 records, kept 0 from target states
# Processed chunk 395: 800,000 records, kept 91,606 from target states
# Processed chunk 396: 800,000 records, kept 800,000 from target states
# Processed chunk 397: 800,000 records, kept 800,000 from target states
# Processed chunk 398: 800,000 records, kept 308,394 from target states
# Processed chunk 399: 800,000 records, kept 291,606 from target states
# Processed chunk 400: 800,000 records, kept 708,394 from target states
# Processed chunk 401: 800,000 records, kept 0 from target states
# Processed chunk 402: 800,000 records, kept 691,606 from target states
# Processed chunk 403: 800,000 records, kept 800,000 from target states
# Processed chunk 404: 800,000 records, kept 508,394 from target states
# Processed chunk 405: 800,000 records, kept 0 from target states
# Processed chunk 406: 800,000 records, kept 0 from target states
# Processed chunk 407: 800,000 records, kept 691,606 from target states
# Processed chunk 408: 800,000 records, kept 800,000 from target states
# Processed chunk 409: 800,000 records, kept 800,000 from target states
# Processed chunk 410: 800,000 records, kept 800,000 from target states
# Processed chunk 411: 800,000 records, kept 800,000 from target states
# Processed chunk 412: 800,000 records, kept 108,394 from target states
# Processed chunk 413: 800,000 records, kept 491,606 from target states
# Processed chunk 414: 800,000 records, kept 508,394 from target states
# Processed chunk 415: 800,000 records, kept 0 from target states
# Processed chunk 416: 800,000 records, kept 0 from target states
# Processed chunk 417: 800,000 records, kept 0 from target states
# Processed chunk 418: 800,000 records, kept 491,606 from target states
# Processed chunk 419: 800,000 records, kept 508,394 from target states
# Processed chunk 420: 800,000 records, kept 91,606 from target states
# Processed chunk 421: 800,000 records, kept 800,000 from target states
# Processed chunk 422: 800,000 records, kept 108,394 from target states
# Processed chunk 423: 800,000 records, kept 491,606 from target states
# Processed chunk 424: 800,000 records, kept 508,394 from target states
# Processed chunk 425: 800,000 records, kept 91,606 from target states
# Processed chunk 426: 800,000 records, kept 800,000 from target states
# Processed chunk 427: 800,000 records, kept 108,394 from target states
# Processed chunk 428: 800,000 records, kept 0 from target states
# Processed chunk 429: 800,000 records, kept 0 from target states
# Processed chunk 430: 800,000 records, kept 91,606 from target states
# Processed chunk 431: 800,000 records, kept 800,000 from target states
# Processed chunk 432: 800,000 records, kept 108,394 from target states
# Processed chunk 433: 800,000 records, kept 0 from target states
# Processed chunk 434: 800,000 records, kept 0 from target states
# Processed chunk 435: 800,000 records, kept 0 from target states
# Processed chunk 436: 800,000 records, kept 0 from target states
# Processed chunk 437: 800,000 records, kept 691,606 from target states
# Processed chunk 438: 800,000 records, kept 308,394 from target states
# Processed chunk 439: 800,000 records, kept 0 from target states
# Processed chunk 440: 800,000 records, kept 0 from target states
# Processed chunk 441: 800,000 records, kept 0 from target states
# Processed chunk 442: 800,000 records, kept 0 from target states
# Processed chunk 443: 800,000 records, kept 0 from target states
# Processed chunk 444: 800,000 records, kept 291,606 from target states
# Processed chunk 445: 800,000 records, kept 708,394 from target states
# Processed chunk 446: 800,000 records, kept 0 from target states
# Processed chunk 447: 800,000 records, kept 0 from target states
# Processed chunk 448: 800,000 records, kept 0 from target states
# Processed chunk 449: 800,000 records, kept 291,606 from target states
# Processed chunk 450: 800,000 records, kept 708,394 from target states
# Processed chunk 451: 800,000 records, kept 0 from target states
# Processed chunk 452: 800,000 records, kept 0 from target states
# Processed chunk 453: 800,000 records, kept 0 from target states
# Processed chunk 454: 800,000 records, kept 291,606 from target states
# Processed chunk 455: 800,000 records, kept 708,394 from target states
# Processed chunk 456: 800,000 records, kept 0 from target states
# Processed chunk 457: 800,000 records, kept 0 from target states
# Processed chunk 458: 800,000 records, kept 0 from target states
# Processed chunk 459: 800,000 records, kept 0 from target states
# Processed chunk 460: 800,000 records, kept 0 from target states
# Processed chunk 461: 800,000 records, kept 0 from target states
# Processed chunk 462: 800,000 records, kept 691,606 from target states
# Processed chunk 463: 800,000 records, kept 308,394 from target states
# Processed chunk 464: 800,000 records, kept 0 from target states
# Processed chunk 465: 800,000 records, kept 0 from target states
# Processed chunk 466: 800,000 records, kept 0 from target states
# Processed chunk 467: 800,000 records, kept 0 from target states
# Processed chunk 468: 800,000 records, kept 491,606 from target states
# Processed chunk 469: 800,000 records, kept 508,394 from target states
# Processed chunk 470: 800,000 records, kept 0 from target states
# Processed chunk 471: 800,000 records, kept 0 from target states
# Processed chunk 472: 800,000 records, kept 691,606 from target states
# Processed chunk 473: 800,000 records, kept 308,394 from target states
# Processed chunk 474: 800,000 records, kept 0 from target states
# Processed chunk 475: 800,000 records, kept 0 from target states
# Processed chunk 476: 800,000 records, kept 0 from target states
# Processed chunk 477: 800,000 records, kept 691,606 from target states
# Processed chunk 478: 800,000 records, kept 308,394 from target states
# Processed chunk 479: 800,000 records, kept 0 from target states
# Processed chunk 480: 800,000 records, kept 91,606 from target states
# Processed chunk 481: 800,000 records, kept 800,000 from target states
# Processed chunk 482: 800,000 records, kept 800,000 from target states
# Processed chunk 483: 800,000 records, kept 308,394 from target states
# Processed chunk 484: 800,000 records, kept 0 from target states
# Processed chunk 485: 800,000 records, kept 0 from target states
# Processed chunk 486: 800,000 records, kept 0 from target states
# Processed chunk 487: 800,000 records, kept 0 from target states
# Processed chunk 488: 800,000 records, kept 491,606 from target states
# Processed chunk 489: 800,000 records, kept 508,394 from target states
# Processed chunk 490: 800,000 records, kept 0 from target states
# Processed chunk 491: 800,000 records, kept 0 from target states
# Processed chunk 492: 800,000 records, kept 0 from target states
# Processed chunk 493: 800,000 records, kept 0 from target states
# Processed chunk 494: 800,000 records, kept 0 from target states
# Processed chunk 495: 800,000 records, kept 0 from target states
# Processed chunk 496: 800,000 records, kept 0 from target states
# ...
# Processed chunk 731: 800,000 records, kept 0 from target states
# Processed chunk 732: 800,000 records, kept 0 from target states
# Processed chunk 733: 800,000 records, kept 0 from target states
# Processed chunk 734: 800,000 records, kept 0 from target states
# Processed chunk 735: 800,000 records, kept 91,606 from target states
# Processed chunk 736: 800,000 records, kept 800,000 from target states
# Processed chunk 737: 800,000 records, kept 108,394 from target states
# Processed chunk 738: 800,000 records, kept 0 from target states
# Processed chunk 739: 800,000 records, kept 0 from target states
# Processed chunk 740: 800,000 records, kept 0 from target states
# Processed chunk 741: 800,000 records, kept 0 from target states
# Processed chunk 742: 800,000 records, kept 0 from target states
# Processed chunk 743: 800,000 records, kept 0 from target states
# Processed chunk 744: 800,000 records, kept 0 from target states
# Processed chunk 745: 800,000 records, kept 0 from target states
# Processed chunk 746: 800,000 records, kept 0 from target states
# Processed chunk 747: 800,000 records, kept 0 from target states
# Processed chunk 748: 800,000 records, kept 0 from target states
# Processed chunk 749: 800,000 records, kept 0 from target states
# Processed chunk 750: 800,000 records, kept 0 from target states
# Processed chunk 751: 800,000 records, kept 0 from target states
# Processed chunk 752: 800,000 records, kept 0 from target states
# Processed chunk 753: 800,000 records, kept 0 from target states
# Processed chunk 754: 800,000 records, kept 0 from target states
# Processed chunk 755: 800,000 records, kept 0 from target states
# Processed chunk 756: 800,000 records, kept 0 from target states
# Processed chunk 757: 800,000 records, kept 0 from target states
# Processed chunk 758: 800,000 records, kept 0 from target states
# Processed chunk 759: 800,000 records, kept 0 from target states
# Processed chunk 760: 800,000 records, kept 0 from target states
# Processed chunk 761: 800,000 records, kept 0 from target states
# Processed chunk 762: 800,000 records, kept 0 from target states
# Processed chunk 763: 800,000 records, kept 0 from target states
# Processed chunk 764: 800,000 records, kept 0 from target states
# Processed chunk 765: 800,000 records, kept 0 from target states
# Processed chunk 766: 800,000 records, kept 0 from target states
# Processed chunk 767: 800,000 records, kept 0 from target states
# Processed chunk 768: 800,000 records, kept 0 from target states
# Processed chunk 769: 800,000 records, kept 0 from target states
# Processed chunk 770: 800,000 records, kept 91,606 from target states
# Processed chunk 771: 800,000 records, kept 800,000 from target states
# Processed chunk 772: 800,000 records, kept 108,394 from target states
# Processed chunk 773: 800,000 records, kept 0 from target states
# Processed chunk 774: 800,000 records, kept 0 from target states
# Processed chunk 775: 800,000 records, kept 0 from target states
# Processed chunk 776: 800,000 records, kept 0 from target states
# Processed chunk 777: 800,000 records, kept 0 from target states
# Processed chunk 778: 800,000 records, kept 491,606 from target states
# Processed chunk 779: 800,000 records, kept 800,000 from target states
# Processed chunk 780: 800,000 records, kept 708,394 from target states
# Processed chunk 781: 800,000 records, kept 0 from target states
# Processed chunk 782: 800,000 records, kept 0 from target states
# Processed chunk 783: 800,000 records, kept 0 from target states
# Processed chunk 784: 800,000 records, kept 0 from target states
# Processed chunk 785: 800,000 records, kept 0 from target states
# Processed chunk 786: 800,000 records, kept 0 from target states
# Processed chunk 787: 800,000 records, kept 0 from target states
# Processed chunk 788: 800,000 records, kept 0 from target states
# Processed chunk 789: 800,000 records, kept 0 from target states
# Processed chunk 790: 800,000 records, kept 0 from target states
# Processed chunk 791: 800,000 records, kept 0 from target states
# Processed chunk 792: 800,000 records, kept 691,606 from target states
# Processed chunk 793: 800,000 records, kept 308,394 from target states
# Processed chunk 794: 800,000 records, kept 0 from target states
# Processed chunk 795: 800,000 records, kept 0 from target states
# Processed chunk 796: 800,000 records, kept 0 from target states
# Processed chunk 797: 800,000 records, kept 0 from target states
# Processed chunk 798: 800,000 records, kept 491,606 from target states
# Processed chunk 799: 800,000 records, kept 508,394 from target states
# Processed chunk 800: 800,000 records, kept 0 from target states
# Processed chunk 801: 800,000 records, kept 0 from target states
# Processed chunk 802: 800,000 records, kept 0 from target states
# Processed chunk 803: 800,000 records, kept 0 from target states
# Processed chunk 804: 800,000 records, kept 0 from target states
# Processed chunk 805: 800,000 records, kept 0 from target states
# Processed chunk 806: 800,000 records, kept 0 from target states
# Processed chunk 807: 800,000 records, kept 691,606 from target states
# Processed chunk 808: 800,000 records, kept 308,394 from target states
# Processed chunk 809: 800,000 records, kept 0 from target states
# Processed chunk 810: 800,000 records, kept 0 from target states
# Processed chunk 811: 800,000 records, kept 0 from target states
# Processed chunk 812: 800,000 records, kept 691,606 from target states
# Processed chunk 813: 800,000 records, kept 308,394 from target states
# Processed chunk 814: 800,000 records, kept 291,606 from target states
# Processed chunk 815: 800,000 records, kept 708,394 from target states
# Processed chunk 816: 800,000 records, kept 0 from target states
# Processed chunk 817: 800,000 records, kept 0 from target states
# Processed chunk 818: 800,000 records, kept 491,606 from target states
# Processed chunk 819: 800,000 records, kept 508,394 from target states
# Processed chunk 820: 800,000 records, kept 91,606 from target states
# Processed chunk 821: 800,000 records, kept 800,000 from target states
# Processed chunk 822: 800,000 records, kept 800,000 from target states
# Processed chunk 823: 800,000 records, kept 800,000 from target states
# Processed chunk 824: 800,000 records, kept 800,000 from target states
# Processed chunk 825: 800,000 records, kept 800,000 from target states
# Processed chunk 826: 800,000 records, kept 800,000 from target states
# Processed chunk 827: 800,000 records, kept 108,394 from target states
# Processed chunk 828: 800,000 records, kept 0 from target states
# Processed chunk 829: 800,000 records, kept 0 from target states
# Processed chunk 830: 800,000 records, kept 0 from target states
# Processed chunk 831: 800,000 records, kept 0 from target states
# Processed chunk 832: 800,000 records, kept 0 from target states
# Processed chunk 833: 800,000 records, kept 0 from target states
# Processed chunk 834: 800,000 records, kept 291,606 from target states
# Processed chunk 835: 800,000 records, kept 800,000 from target states
# Processed chunk 836: 800,000 records, kept 800,000 from target states
# Processed chunk 837: 800,000 records, kept 108,394 from target states
# Processed chunk 838: 800,000 records, kept 0 from target states
# Processed chunk 839: 800,000 records, kept 0 from target states
# Processed chunk 840: 800,000 records, kept 0 from target states
# Processed chunk 841: 800,000 records, kept 0 from target states
# Processed chunk 842: 800,000 records, kept 0 from target states
# Processed chunk 843: 800,000 records, kept 491,606 from target states
# Processed chunk 844: 800,000 records, kept 800,000 from target states
# Processed chunk 845: 800,000 records, kept 708,394 from target states
# Processed chunk 846: 800,000 records, kept 0 from target states
# Processed chunk 847: 800,000 records, kept 0 from target states
# Processed chunk 848: 800,000 records, kept 491,606 from target states
# Processed chunk 849: 800,000 records, kept 508,394 from target states
# Processed chunk 850: 800,000 records, kept 0 from target states
# Processed chunk 851: 800,000 records, kept 0 from target states
# Processed chunk 852: 800,000 records, kept 0 from target states
# Processed chunk 853: 800,000 records, kept 0 from target states
# Processed chunk 854: 800,000 records, kept 0 from target states
# Processed chunk 855: 800,000 records, kept 0 from target states
# Processed chunk 856: 800,000 records, kept 0 from target states
# Processed chunk 857: 800,000 records, kept 0 from target states
# Processed chunk 858: 800,000 records, kept 491,606 from target states
# Processed chunk 859: 800,000 records, kept 800,000 from target states
# Processed chunk 860: 800,000 records, kept 708,394 from target states
# Processed chunk 861: 800,000 records, kept 0 from target states
# Processed chunk 862: 800,000 records, kept 0 from target states
# Processed chunk 863: 800,000 records, kept 0 from target states
# Processed chunk 864: 800,000 records, kept 0 from target states
# Processed chunk 865: 800,000 records, kept 0 from target states
# Processed chunk 866: 800,000 records, kept 0 from target states
# Processed chunk 867: 800,000 records, kept 0 from target states
# Processed chunk 868: 800,000 records, kept 0 from target states
# Processed chunk 869: 800,000 records, kept 0 from target states
# Processed chunk 870: 800,000 records, kept 0 from target states
# Processed chunk 871: 800,000 records, kept 0 from target states
# Processed chunk 872: 800,000 records, kept 0 from target states
# Processed chunk 873: 800,000 records, kept 0 from target states
# Processed chunk 874: 800,000 records, kept 0 from target states
# Processed chunk 875: 800,000 records, kept 0 from target states
# Processed chunk 876: 800,000 records, kept 0 from target states
# Processed chunk 877: 800,000 records, kept 0 from target states
# Processed chunk 878: 800,000 records, kept 0 from target states
# Processed chunk 879: 800,000 records, kept 0 from target states
# Processed chunk 880: 800,000 records, kept 0 from target states
# Processed chunk 881: 800,000 records, kept 0 from target states
# Processed chunk 882: 800,000 records, kept 0 from target states
# Processed chunk 883: 800,000 records, kept 0 from target states
# Processed chunk 884: 800,000 records, kept 0 from target states
# Processed chunk 885: 800,000 records, kept 0 from target states
# Processed chunk 886: 800,000 records, kept 0 from target states
# Processed chunk 887: 800,000 records, kept 0 from target states
# Processed chunk 888: 800,000 records, kept 0 from target states
# Processed chunk 889: 800,000 records, kept 0 from target states
# Processed chunk 890: 800,000 records, kept 0 from target states
# Processed chunk 891: 800,000 records, kept 0 from target states
# Processed chunk 892: 800,000 records, kept 0 from target states
# Processed chunk 893: 800,000 records, kept 0 from target states
# Processed chunk 894: 800,000 records, kept 0 from target states
# Processed chunk 895: 800,000 records, kept 91,606 from target states
# Processed chunk 896: 800,000 records, kept 800,000 from target states
# Processed chunk 897: 800,000 records, kept 800,000 from target states
# Processed chunk 898: 800,000 records, kept 308,394 from target states
# Processed chunk 899: 800,000 records, kept 0 from target states
# Processed chunk 900: 800,000 records, kept 0 from target states
# Processed chunk 901: 800,000 records, kept 0 from target states
# Processed chunk 902: 800,000 records, kept 0 from target states
# Processed chunk 903: 800,000 records, kept 491,606 from target states
# Processed chunk 904: 800,000 records, kept 800,000 from target states
# Processed chunk 905: 800,000 records, kept 708,394 from target states
# Processed chunk 906: 800,000 records, kept 0 from target states
# Processed chunk 907: 800,000 records, kept 0 from target states
# Processed chunk 908: 800,000 records, kept 0 from target states
# Processed chunk 909: 800,000 records, kept 0 from target states
# Processed chunk 910: 800,000 records, kept 91,606 from target states
# Processed chunk 911: 800,000 records, kept 800,000 from target states
# Processed chunk 912: 800,000 records, kept 108,394 from target states
# Processed chunk 913: 800,000 records, kept 491,606 from target states
# Processed chunk 914: 800,000 records, kept 800,000 from target states
# Processed chunk 915: 800,000 records, kept 708,394 from target states
# Processed chunk 916: 800,000 records, kept 0 from target states
# Processed chunk 917: 800,000 records, kept 0 from target states
# Processed chunk 918: 800,000 records, kept 0 from target states
# Processed chunk 919: 800,000 records, kept 0 from target states
# Processed chunk 920: 800,000 records, kept 0 from target states
# Processed chunk 921: 800,000 records, kept 0 from target states
# Processed chunk 922: 800,000 records, kept 691,606 from target states
# Processed chunk 923: 800,000 records, kept 308,394 from target states
# Processed chunk 924: 800,000 records, kept 291,606 from target states
# Processed chunk 925: 800,000 records, kept 708,394 from target states
# Processed chunk 926: 800,000 records, kept 0 from target states
# Processed chunk 927: 800,000 records, kept 0 from target states
# Processed chunk 928: 800,000 records, kept 0 from target states
# Processed chunk 929: 800,000 records, kept 0 from target states
# Processed chunk 930: 800,000 records, kept 91,606 from target states
# Processed chunk 931: 800,000 records, kept 800,000 from target states
# Processed chunk 932: 800,000 records, kept 108,394 from target states
# Processed chunk 933: 800,000 records, kept 0 from target states
# Processed chunk 934: 800,000 records, kept 0 from target states
# Processed chunk 935: 800,000 records, kept 0 from target states
# Processed chunk 936: 800,000 records, kept 0 from target states
# Processed chunk 937: 800,000 records, kept 691,606 from target states
# Processed chunk 938: 800,000 records, kept 308,394 from target states
# Processed chunk 939: 800,000 records, kept 0 from target states
# Processed chunk 940: 800,000 records, kept 0 from target states
# Processed chunk 941: 800,000 records, kept 0 from target states
# Processed chunk 942: 800,000 records, kept 0 from target states
# Processed chunk 943: 800,000 records, kept 0 from target states
# Processed chunk 944: 800,000 records, kept 0 from target states
# Processed chunk 945: 800,000 records, kept 0 from target states
# Processed chunk 946: 800,000 records, kept 0 from target states
# Processed chunk 947: 800,000 records, kept 0 from target states
# Processed chunk 948: 800,000 records, kept 491,606 from target states
# Processed chunk 949: 800,000 records, kept 800,000 from target states
# Processed chunk 950: 708,394 records, kept 708,394 from target states
#
# Processing complete:
#   Total records scanned: 759,908,394
#   Records from target states: 155,220,638 (20.4%)
#   Final aggregated rows: 7,828
#      BUYER_STATE BUYER_COUNTY  YEAR     TOTAL_MME  \
# 1382          GA       COFFEE  2017  9.154432e+07
# 5369          NC   PERQUIMANS  2019  7.376052e+06
# 4225          MT      ROSEBUD  2014  5.836508e+06
# 7479          WA       ISLAND  2007  4.723821e+07
# 6126          OR         POLK  2006  3.030639e+07
# 2721          GA      TELFAIR  2019  2.856540e+07
# 5449          NC      ROBESON  2015  2.178946e+08
# 4776          NC        DAVIE  2007  3.590974e+07
# 231           FL      FLAGLER  2013  1.187053e+08
# 4524          NC     BUNCOMBE  2010  5.797865e+08
#
#                                           BUYER_BUS_ACT  unique_buyers
# 1382  CHAIN PHARMACY,HOSPITAL/CLINIC,PRACTITIONER,RE...            155
# 5369              MLP-AMBULANCE SERVICE,RETAIL PHARMACY             22
# 4225  HOSP/CLINIC FED,HOSPITAL/CLINIC,PRACTITIONER,R...             22
# 7479  CHAIN PHARMACY,HOSP/CLINIC- MIL,HOSPITAL/CLINI...            415
# 6126  CHAIN PHARMACY,HOSPITAL/CLINIC,PRACTITIONER,RE...            187
# 2721        CHAIN PHARMACY,PRACTITIONER,RETAIL PHARMACY             32
# 5449  CHAIN PHARMACY,HOSPITAL/CLINIC,MAINTENANCE,PRA...            394
# 4776  CHAIN PHARMACY,HOSPITAL/CLINIC,MLP-NURSE PRACT...            327
# 231   CHAIN PHARMACY,HOSPITAL/CLINIC,PRACTITIONER,PR...            805
# 4524  CHAIN PHARMACY,DISTRIBUTOR,HOSP/CLINIC-VA,HOSP...           2128

# %%
print("Running validation checks on aggregated ARCOS data...\n")

# Check for duplicates after aggregation
dupe_count = check_duplicates(df, ["BUYER_STATE", "BUYER_COUNTY", "YEAR"])
if dupe_count > 0:
    print(f"ERROR: Found {dupe_count} duplicates after aggregation")
    print("Removing duplicates...")
    df = df.drop_duplicates(
        subset=["BUYER_STATE", "BUYER_COUNTY", "YEAR"], keep="first"
    )

# Validate year range (ARCOS data is 2006-2015)
invalid_years = validate_year_range(df, "YEAR", 2006, 2015)

# Check for negative or zero MME values
invalid_mme = validate_positive_values(df, "TOTAL_MME", allow_zero=False)
if invalid_mme > 0:
    print(f"Removing {invalid_mme} records with invalid MME values")
    df = df[df["TOTAL_MME"] > 0].copy()

# Check state coverage
states_found = df["BUYER_STATE"].unique()
states_missing = set(selected_states) - set(states_found)
if states_missing:
    print(f"Warning: Missing data for states: {states_missing}")
else:
    print(f"All {len(selected_states)} target states have data")

# Distribution check
print(f"\nData distribution by state:")
print(df.groupby("BUYER_STATE").size().sort_values(ascending=False))

print(f"\nMME statistics:")
print(f"  Total MME: {df['TOTAL_MME'].sum():,.0f} mg")
print(f"  Mean per county-year: {df['TOTAL_MME'].mean():,.0f} mg")
print(f"  Median per county-year: {df['TOTAL_MME'].median():,.0f} mg")

print("\nValidation complete.")
# Out:
# Running validation checks on aggregated ARCOS data...
#
# Warning: 2245 records with years outside 2006-2015
#   Year range found: 2006 to 2019
# All 9 target states have data
#
# Data distribution by state:
# BUYER_STATE
# GA    2127
# NC    1382
# FL     936
# MT     731
# SC     644
# ID     586
# WA     546
# OR     496
# UT     380
# dtype: int64
#
# MME statistics:
#   Total MME: 3,641,135,146,453,877 mg
#   Mean per county-year: 465,142,456,113 mg
#   Median per county-year: 31,445,927 mg
#
# Validation complete.

# %%
import os

# Export to clean data folder with proper naming
output_path = "../01_data/clean/arcos_by_county_year.csv"

# Ensure directory exists
os.makedirs(os.path.dirname(output_path), exist_ok=True)

# Save as CSV for compatibility with downstream notebooks
df.to_csv(output_path, index=False)

print(f"Dataset exported to {output_path}")
print(f"Rows exported: {len(df):,}")
print(f"Columns: {list(df.columns)}")
# Out:
# Dataset exported to ../01_data/clean/arcos_by_county_year.csv
# Rows exported: 7,828
# Columns: ['BUYER_STATE', 'BUYER_COUNTY', 'YEAR', 'TOTAL_MME', 'BUYER_BUS_ACT', 'unique_buyers']

# %% [markdown]
# ### Export Cleaned Data
#
# Save the aggregated ARCOS dataset to the clean data folder.

# %%
print("Running final validation checks...\n")

# Check for missing values in key columns
print("Missing value check:")
for col in df.columns:
    missing_count = df[col].isna().sum()
    if missing_count > 0:
        print(f"  {col}: {missing_count} missing ({100*missing_count/len(df):.1f}%)")
    else:
        print(f"  {col}: 0 missing")

# Verify no duplicates remain
final_dupes = check_duplicates(df, ["BUYER_STATE", "BUYER_COUNTY", "YEAR"])
assert final_dupes == 0, "Duplicates found in final dataset"

# Check data ranges
print(f"\nValue ranges:")
print(f"  Years: {df['YEAR'].min()} to {df['YEAR'].max()}")
print(
    f"  Total MME range: {df['TOTAL_MME'].min():,.0f} to {df['TOTAL_MME'].max():,.0f}"
)
print(f"  Counties per state: {df.groupby('BUYER_STATE').size().describe()}")

# Temporal completeness check
print(f"\nTemporal coverage by state:")
for state in sorted(df["BUYER_STATE"].unique()):
    state_data = df[df["BUYER_STATE"] == state]
    years = sorted(state_data["YEAR"].unique())
    print(f"  {state}: {len(years)} years ({min(years)}-{max(years)})")

# Summary statistics
print(f"\nFinal dataset summary:")
print(f"  Total rows: {len(df):,}")
print(f"  States: {df['BUYER_STATE'].nunique()}")
print(f"  Counties: {df['BUYER_COUNTY'].nunique()}")
print(f"  Years: {df['YEAR'].nunique()}")
print(f"  Total MME: {df['TOTAL_MME'].sum():,.0f} mg")

print("\nValidation passed. Ready for export.")
# Out:
# Running final validation checks...
#
# Missing value check:
#   BUYER_STATE: 0 missing
#   BUYER_COUNTY: 0 missing
#   YEAR: 0 missing
#   TOTAL_MME: 0 missing
#   BUYER_BUS_ACT: 0 missing
#   unique_buyers: 0 missing
#
# Value ranges:
#   Years: 2006 to 2019
#   Total MME range: 0 to 740,037,027,208,646
#   Counties per state: count       9.000000
# mean      869.777778
# std       557.063008
# min       380.000000
# 25%       546.000000
# 50%       644.000000
# 75%       936.000000
# max      2127.000000
# dtype: float64
#
# Temporal coverage by state:
#   FL: 14 years (2006-2019)
#   GA: 14 years (2006-2019)
#   ID: 14 years (2006-2019)
#   MT: 14 years (2006-2019)
#   NC: 14 years (2006-2019)
#   OR: 14 years (2006-2019)
#   SC: 14 years (2006-2019)
#   UT: 14 years (2006-2019)
#   WA: 14 years (2006-2019)
#
# Final dataset summary:
#   Total rows: 7,828
#   States: 9
#   Counties: 467
#   Years: 14
#   Total MME: 3,641,135,146,453,877 mg
#
# Validation passed. Ready for export.
