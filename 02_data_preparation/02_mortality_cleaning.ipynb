# %% [markdown]
# ## Mortality Data Cleaning
#
# Process CDC mortality data (2003-2015) and merge with population estimates.

# %% [markdown]
# ### Import Libraries

# %%
# Import libraries
import requests
import zipfile
import io
import pandas as pd
import numpy as np

pd.set_option("mode.copy_on_write", True)

# %% [markdown]
# ### Load Mortality Data

# %%
# Load mortality data from zip archive
url = "https://www.dropbox.com/scl/fi/bnkoej224ve1tr35fhek8/US_VitalStatistics.zip?rlkey=oenpdsvsiovlqw7v7j1yhldye&dl=1"

resp = requests.get(url)
resp.raise_for_status()
zip_bytes = io.BytesIO(resp.content)

dfs = []

with zipfile.ZipFile(zip_bytes, "r") as zf:
    txt_files = [
        name
        for name in zf.namelist()
        if name.lower().endswith(".txt")
        and "__macosx" not in name.lower()
        and "/._" not in name
    ]

    for name in sorted(txt_files):
        print("Reading:", name)
        with zf.open(name) as f:
            df = pd.read_csv(f, sep="\t", encoding="latin1")
            dfs.append(df)

mortality_03_15 = pd.concat(dfs, ignore_index=True)

print("Number of files read:", len(dfs))
print("Final dataframe shape:", mortality_03_15.shape)
mortality_03_15.sample(20)
# Out:
# Reading: Underlying Cause of Death, 2003.txt
# Reading: Underlying Cause of Death, 2004.txt
# Reading: Underlying Cause of Death, 2005.txt
# Reading: Underlying Cause of Death, 2006.txt
# Reading: Underlying Cause of Death, 2007.txt
# Reading: Underlying Cause of Death, 2008.txt
# Reading: Underlying Cause of Death, 2009.txt
# Reading: Underlying Cause of Death, 2010.txt
# Reading: Underlying Cause of Death, 2011.txt
# Reading: Underlying Cause of Death, 2012.txt
# Reading: Underlying Cause of Death, 2013.txt
# Reading: Underlying Cause of Death, 2014.txt
# Reading: Underlying Cause of Death, 2015.txt
# Number of files read: 13
# Final dataframe shape: (57436, 8)
#       Notes                 County  County Code    Year  Year Code  \
# 55565   NaN      Gaston County, NC      37071.0  2015.0     2015.0
# 42889   NaN    Franklin County, VT      50011.0  2012.0     2012.0
# 14127   NaN  Dorchester County, MD      24019.0  2006.0     2006.0
# 51504   NaN   Clarendon County, SC      45027.0  2014.0     2014.0
# 17150   NaN     Ventura County, CA       6111.0  2007.0     2007.0
# 12211   NaN      Chelan County, WA      53007.0  2005.0     2005.0
# 31935   NaN        Pike County, MS      28113.0  2010.0     2010.0
# 45581   NaN    Crawford County, MO      29055.0  2013.0     2013.0
# 31994   NaN    Crawford County, MO      29055.0  2010.0     2010.0
# 6505    NaN       Bronx County, NY      36005.0  2004.0     2004.0
# 23428   NaN      Platte County, NE      31141.0  2008.0     2008.0
# 42579   NaN     Coryell County, TX      48099.0  2012.0     2012.0
# 23614   NaN       Bronx County, NY      36005.0  2008.0     2008.0
# 51222   NaN      Nowata County, OK      40105.0  2014.0     2014.0
# 50900   NaN     Robeson County, NC      37155.0  2014.0     2014.0
# 55754   NaN  Columbiana County, OH      39029.0  2015.0     2015.0
# 11638   NaN      Monroe County, TN      47123.0  2005.0     2005.0
# 9557    NaN   Jefferson County, KS      20087.0  2005.0     2005.0
# 36799   NaN       Ocean County, NJ      34029.0  2011.0     2011.0
# 28914   NaN    Davidson County, TN      47037.0  2009.0     2009.0
#
#                               Drug/Alcohol Induced Cause  \
# 55565                   All other alcohol-induced causes
# 42889          All other non-drug and non-alcohol causes
# 14127          All other non-drug and non-alcohol causes
# 51504          All other non-drug and non-alcohol causes
# 17150                   All other alcohol-induced causes
# 12211          All other non-drug and non-alcohol causes
# 31935          All other non-drug and non-alcohol causes
# 45581          All other non-drug and non-alcohol causes
# 31994          All other non-drug and non-alcohol causes
# 6505                    All other alcohol-induced causes
# 23428          All other non-drug and non-alcohol causes
# 42579          All other non-drug and non-alcohol causes
# 23614                   All other alcohol-induced causes
# 51222          All other non-drug and non-alcohol causes
# 50900          All other non-drug and non-alcohol causes
# 55754          All other non-drug and non-alcohol causes
# 11638          All other non-drug and non-alcohol causes
# 9557           All other non-drug and non-alcohol causes
# 36799                   All other alcohol-induced causes
# 28914  Drug poisonings (overdose) Unintentional (X40-...
#
#       Drug/Alcohol Induced Cause Code  Deaths
# 55565                              A9      24
# 42889                              O9   365.0
# 14127                              O9   366.0
# 51504                              O9   400.0
# 17150                              A9    61.0
# 12211                              O9   597.0
# 31935                              O9   495.0
# 45581                              O9   266.0
# 31994                              O9   273.0
# 6505                               A9   125.0
# 23428                              O9   242.0
# 42579                              O9   387.0
# 23614                              A9   112.0
# 51222                              O9   140.0
# 50900                              O9  1265.0
# 55754                              O9    1291
# 11638                              O9   458.0
# 9557                               O9   177.0
# 36799                              A9    34.0
# 28914                              D1    90.0

# %% [markdown]
# ### Initial Data Exploration

# %%
# Show column names
mortality_03_15.columns
# Out:
# Index(['Notes', 'County', 'County Code', 'Year', 'Year Code',
#        'Drug/Alcohol Induced Cause', 'Drug/Alcohol Induced Cause Code',
#        'Deaths'],
#       dtype='object')

# %%
# Check missing values
mortality_03_15.isna().sum()
# Out:
# Notes                              57241
# County                               195
# County Code                          195
# Year                                 195
# Year Code                            195
# Drug/Alcohol Induced Cause           195
# Drug/Alcohol Induced Cause Code      195
# Deaths                               195
# dtype: int64

# %%
# Check for duplicate rows
mortality_03_15.duplicated().sum()
# Out:
# np.int64(183)

# %%
# Display duplicated rows
mortality_03_15[mortality_03_15.duplicated()]
# Out:
#                                                    Notes County  County Code  \
# 4094                                                 ---    NaN          NaN
# 4096                                                 ---    NaN          NaN
# 4101                                                 ---    NaN          NaN
# 8237                                                 ---    NaN          NaN
# 8238       Dataset: Underlying Cause of Death, 1999-2017    NaN          NaN
# ...                                                  ...    ...          ...
# 57431  Suggested Citation: Centers for Disease Contro...    NaN          NaN
# 57432  1999-2017 on CDC WONDER Online Database, relea...    NaN          NaN
# 57433  compiled from data provided by the 57 vital st...    NaN          NaN
# 57434  at http://wonder.cdc.gov/ucd-icd10.html on Oct...    NaN          NaN
# 57435                                                ---    NaN          NaN
#
#        Year  Year Code Drug/Alcohol Induced Cause  \
# 4094    NaN        NaN                        NaN
# 4096    NaN        NaN                        NaN
# 4101    NaN        NaN                        NaN
# 8237    NaN        NaN                        NaN
# 8238    NaN        NaN                        NaN
# ...     ...        ...                        ...
# 57431   NaN        NaN                        NaN
# 57432   NaN        NaN                        NaN
# 57433   NaN        NaN                        NaN
# 57434   NaN        NaN                        NaN
# 57435   NaN        NaN                        NaN
#
#       Drug/Alcohol Induced Cause Code Deaths
# 4094                              NaN    NaN
# 4096                              NaN    NaN
# 4101                              NaN    NaN
# 8237                              NaN    NaN
# 8238                              NaN    NaN
# ...                               ...    ...
# 57431                             NaN    NaN
# 57432                             NaN    NaN
# 57433                             NaN    NaN
# 57434                             NaN    NaN
# 57435                             NaN    NaN
#
# [183 rows x 8 columns]

# %%
# Copy dataframe for cleaning
mortality_03_15_clean = mortality_03_15.copy()

# %% [markdown]
# ### Handle Missing Values

# %%
# Check missing values after copy
mortality_03_15_clean.isna().sum()
# Out:
# Notes                              57241
# County                               195
# County Code                          195
# Year                                 195
# Year Code                            195
# Drug/Alcohol Induced Cause           195
# Drug/Alcohol Induced Cause Code      195
# Deaths                               195
# dtype: int64

# %%
# Identify unusual missing value indicators
for col in mortality_03_15_clean.columns:
    uniques = mortality_03_15_clean[col].astype(str).unique()
    unusual = [
        u
        for u in uniques
        if u.strip().lower()
        in ["missing", "n/a", "na", "none", ".", "null", "suppressed", ""]
    ]
    if unusual:
        print(f"{col}: {unusual}")
# Out:
# Deaths: ['Missing']

# %%
# Show rows with 'Missing' in Deaths column
mortality_03_15_clean[mortality_03_15_clean["Deaths"] == "Missing"]
# Out:
#       Notes                                           County  County Code  \
# 52756   NaN  Prince of Wales-Outer Ketchikan Census Area, AK       2201.0
# 52757   NaN  Prince of Wales-Outer Ketchikan Census Area, AK       2201.0
# 52758   NaN  Prince of Wales-Outer Ketchikan Census Area, AK       2201.0
# 52759   NaN  Prince of Wales-Outer Ketchikan Census Area, AK       2201.0
# 52760   NaN  Prince of Wales-Outer Ketchikan Census Area, AK       2201.0
# 52761   NaN  Prince of Wales-Outer Ketchikan Census Area, AK       2201.0
# 52762   NaN  Prince of Wales-Outer Ketchikan Census Area, AK       2201.0
# 52763   NaN  Prince of Wales-Outer Ketchikan Census Area, AK       2201.0
# 52765   NaN            Skagway-Hoonah-Angoon Census Area, AK       2232.0
# 52766   NaN            Skagway-Hoonah-Angoon Census Area, AK       2232.0
# 52767   NaN            Skagway-Hoonah-Angoon Census Area, AK       2232.0
# 52768   NaN            Skagway-Hoonah-Angoon Census Area, AK       2232.0
# 52769   NaN            Skagway-Hoonah-Angoon Census Area, AK       2232.0
# 52770   NaN            Skagway-Hoonah-Angoon Census Area, AK       2232.0
# 52771   NaN            Skagway-Hoonah-Angoon Census Area, AK       2232.0
# 52772   NaN            Skagway-Hoonah-Angoon Census Area, AK       2232.0
# 52777   NaN              Wrangell-Petersburg Census Area, AK       2280.0
# 52778   NaN              Wrangell-Petersburg Census Area, AK       2280.0
# 52779   NaN              Wrangell-Petersburg Census Area, AK       2280.0
# 52780   NaN              Wrangell-Petersburg Census Area, AK       2280.0
# 52781   NaN              Wrangell-Petersburg Census Area, AK       2280.0
# 52782   NaN              Wrangell-Petersburg Census Area, AK       2280.0
# 52783   NaN              Wrangell-Petersburg Census Area, AK       2280.0
# 52784   NaN              Wrangell-Petersburg Census Area, AK       2280.0
# 57048   NaN                                 Bedford city, VA      51515.0
# 57049   NaN                                 Bedford city, VA      51515.0
# 57050   NaN                                 Bedford city, VA      51515.0
# 57051   NaN                                 Bedford city, VA      51515.0
# 57052   NaN                                 Bedford city, VA      51515.0
# 57053   NaN                                 Bedford city, VA      51515.0
# 57054   NaN                                 Bedford city, VA      51515.0
# 57055   NaN                                 Bedford city, VA      51515.0
# 57062   NaN                           Clifton Forge city, VA      51560.0
# 57063   NaN                           Clifton Forge city, VA      51560.0
# 57064   NaN                           Clifton Forge city, VA      51560.0
# 57065   NaN                           Clifton Forge city, VA      51560.0
# 57066   NaN                           Clifton Forge city, VA      51560.0
# 57067   NaN                           Clifton Forge city, VA      51560.0
# 57068   NaN                           Clifton Forge city, VA      51560.0
# 57069   NaN                           Clifton Forge city, VA      51560.0
#
#          Year  Year Code                         Drug/Alcohol Induced Cause  \
# 52756  2015.0     2015.0  Drug poisonings (overdose) Unintentional (X40-...
# 52757  2015.0     2015.0       Drug poisonings (overdose) Suicide (X60-X64)
# 52758  2015.0     2015.0          Drug poisonings (overdose) Homicide (X85)
# 52759  2015.0     2015.0  Drug poisonings (overdose) Undetermined (Y10-Y14)
# 52760  2015.0     2015.0                      All other drug-induced causes
# 52761  2015.0     2015.0      Alcohol poisonings (overdose) (X45, X65, Y15)
# 52762  2015.0     2015.0                   All other alcohol-induced causes
# 52763  2015.0     2015.0          All other non-drug and non-alcohol causes
# 52765  2015.0     2015.0  Drug poisonings (overdose) Unintentional (X40-...
# 52766  2015.0     2015.0       Drug poisonings (overdose) Suicide (X60-X64)
# 52767  2015.0     2015.0          Drug poisonings (overdose) Homicide (X85)
# 52768  2015.0     2015.0  Drug poisonings (overdose) Undetermined (Y10-Y14)
# 52769  2015.0     2015.0                      All other drug-induced causes
# 52770  2015.0     2015.0      Alcohol poisonings (overdose) (X45, X65, Y15)
# 52771  2015.0     2015.0                   All other alcohol-induced causes
# 52772  2015.0     2015.0          All other non-drug and non-alcohol causes
# 52777  2015.0     2015.0  Drug poisonings (overdose) Unintentional (X40-...
# 52778  2015.0     2015.0       Drug poisonings (overdose) Suicide (X60-X64)
# 52779  2015.0     2015.0          Drug poisonings (overdose) Homicide (X85)
# 52780  2015.0     2015.0  Drug poisonings (overdose) Undetermined (Y10-Y14)
# 52781  2015.0     2015.0                      All other drug-induced causes
# 52782  2015.0     2015.0      Alcohol poisonings (overdose) (X45, X65, Y15)
# 52783  2015.0     2015.0                   All other alcohol-induced causes
# 52784  2015.0     2015.0          All other non-drug and non-alcohol causes
# 57048  2015.0     2015.0  Drug poisonings (overdose) Unintentional (X40-...
# 57049  2015.0     2015.0       Drug poisonings (overdose) Suicide (X60-X64)
# 57050  2015.0     2015.0          Drug poisonings (overdose) Homicide (X85)
# 57051  2015.0     2015.0  Drug poisonings (overdose) Undetermined (Y10-Y14)
# 57052  2015.0     2015.0                      All other drug-induced causes
# 57053  2015.0     2015.0      Alcohol poisonings (overdose) (X45, X65, Y15)
# 57054  2015.0     2015.0                   All other alcohol-induced causes
# 57055  2015.0     2015.0          All other non-drug and non-alcohol causes
# 57062  2015.0     2015.0  Drug poisonings (overdose) Unintentional (X40-...
# 57063  2015.0     2015.0       Drug poisonings (overdose) Suicide (X60-X64)
# 57064  2015.0     2015.0          Drug poisonings (overdose) Homicide (X85)
# 57065  2015.0     2015.0  Drug poisonings (overdose) Undetermined (Y10-Y14)
# 57066  2015.0     2015.0                      All other drug-induced causes
# 57067  2015.0     2015.0      Alcohol poisonings (overdose) (X45, X65, Y15)
# 57068  2015.0     2015.0                   All other alcohol-induced causes
# 57069  2015.0     2015.0          All other non-drug and non-alcohol causes
#
#       Drug/Alcohol Induced Cause Code   Deaths
# 52756                              D1  Missing
# 52757                              D2  Missing
# 52758                              D3  Missing
# 52759                              D4  Missing
# 52760                              D9  Missing
# 52761                              A1  Missing
# 52762                              A9  Missing
# 52763                              O9  Missing
# 52765                              D1  Missing
# 52766                              D2  Missing
# 52767                              D3  Missing
# 52768                              D4  Missing
# 52769                              D9  Missing
# 52770                              A1  Missing
# 52771                              A9  Missing
# 52772                              O9  Missing
# 52777                              D1  Missing
# 52778                              D2  Missing
# 52779                              D3  Missing
# 52780                              D4  Missing
# 52781                              D9  Missing
# 52782                              A1  Missing
# 52783                              A9  Missing
# 52784                              O9  Missing
# 57048                              D1  Missing
# 57049                              D2  Missing
# 57050                              D3  Missing
# 57051                              D4  Missing
# 57052                              D9  Missing
# 57053                              A1  Missing
# 57054                              A9  Missing
# 57055                              O9  Missing
# 57062                              D1  Missing
# 57063                              D2  Missing
# 57064                              D3  Missing
# 57065                              D4  Missing
# 57066                              D9  Missing
# 57067                              A1  Missing
# 57068                              A9  Missing
# 57069                              O9  Missing

# %%
# Replace 'Missing' with NaN in Deaths column
mortality_03_15_clean["Deaths"] = mortality_03_15_clean["Deaths"].replace(
    "Missing", np.nan
)

# %% [markdown]
# ### Load Population Data

# %%
# Load population data
population = pd.read_csv("../01_data/clean/population_2000_2024.csv")
print(f"Population data shape: {population.shape}")
# Out:
# Population data shape: (21996, 7)

# %% [markdown]
# ### Standardize FIPS Codes

# %%
# Standardize FIPS codes
mortality_03_15_clean["County Code"] = (
    mortality_03_15_clean["County Code"].astype(str).str.zfill(5)
)
population["fips"] = population["fips"].astype(str).str.zfill(5)

# %% [markdown]
# ### Filter Data

# %%
# Filter out obsolete FIPS and select relevant cause code
obsolete_fips = ["02201", "02232", "02280", "02270", "46113", "51515", "51560"]

mortality_03_15_clean = mortality_03_15_clean[
    ~mortality_03_15_clean["County Code"].isin(obsolete_fips)
]

mortality_03_15_clean = mortality_03_15_clean[
    mortality_03_15_clean["Drug/Alcohol Induced Cause Code"] == "D1"
]

print(f"Filtered mortality data shape: {mortality_03_15_clean.shape}")
# Out:
# Filtered mortality data shape: (7573, 8)

# %% [markdown]
# ### Merge Datasets

# %%
# Merge mortality and population data
mortality_03_15_clean["Year"] = mortality_03_15_clean["Year"].astype(int)
mortality_03_15_clean["County Code"] = mortality_03_15_clean["County Code"].str.replace(
    ".0", "", regex=False
)

pop_mortality_merged = pd.merge(
    mortality_03_15_clean,
    population,
    left_on=["County Code", "Year"],
    right_on=["fips", "year"],
    how="inner",
)

print(f"Merged data shape: {pop_mortality_merged.shape}")
# Out:
# Merged data shape: (2216, 15)

# %% [markdown]
# ### Export Cleaned Data

# %%
# Export merged data
pop_mortality_merged.to_csv(
    "../01_data/clean/merged_mortality_population.csv", index=False
)
print("Exported to: ../01_data/clean/merged_mortality_population.csv")
# Out:
# Exported to: ../01_data/clean/merged_mortality_population.csv
